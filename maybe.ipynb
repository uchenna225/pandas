# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col = "Respondent")
schemea = pd.read_csv('survey_results_schema.csv', index_col = "Column")
# we can set index here as well as we are creating our data frame by passing in additional args like in schemea

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
# to get multiple series(columns) 
df[["Hobbyist", "Student"]]
# Out:
#            Hobbyist         Student
# Respondent
# 1               Yes              No
# 2                No  Yes, full-time
# 3               Yes              No
# 4                No              No
# 5               Yes              No
# ...             ...             ...
# 88377           Yes              No
# 88601            No             NaN
# 88802            No             NaN
# 88816            No             NaN
# 88863           Yes  Yes, full-time
#
# [88883 rows x 2 columns]

# %%
# pd.set_option('display.max_columns',85)
# pd.set_option('display.max_rows', 85)

# %%
# pd.set_option('display.max_row', None)
# to show the maximum rolls

# %%
schemea["QuestionText"].sort_index()
# Out:
# Column
# Age              What is your age (in years)? If you prefer not...
# Age1stCode       At what age did you write your first line of c...
# BetterLife       Do you think people born today will have a bet...
# BlockchainIs     Blockchain / cryptocurrency technology is prim...
# BlockchainOrg    How is your organization thinking about or imp...
#                                        ...
# WorkPlan                   How structured or planned is your work?
# WorkRemote                         How often do you work remotely?
# WorkWeekHrs       On average, how many hours per week do you work?
# YearsCode        Including any education, how many years have y...
# YearsCodePro     How many years have you coded professionally (...
# Name: QuestionText, Length: 85, dtype: object

# %%
df.iloc[0]
# Out:
# MainBranch                 I am a student who is learning to code
# Hobbyist                                                      Yes
# OpenSourcer                                                 Never
# OpenSource      The quality of OSS and closed source software ...
# Employment                 Not employed, and not looking for work
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                                                     NaN
# Dependents                                                     No
# SurveyLength                                Appropriate in length
# SurveyEase                             Neither easy nor difficult
# Name: 1, Length: 84, dtype: object

# %%
# to get n numbers of column row use 2 brackets 
df.iloc[[0, 5]]
# meanwhile if i want to get the colums i input the index of the column i want
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 6           I am not primarily a developer, but I write co...      Yes
#
#            OpenSourcer                                         OpenSource  \
# Respondent
# 1                Never  The quality of OSS and closed source software ...
# 6                Never  The quality of OSS and closed source software ...
#
#                                         Employment         Country Student  \
# Respondent
# 1           Not employed, and not looking for work  United Kingdom      No
# 6                               Employed full-time          Canada      No
#
#                                              EdLevel  \
# Respondent
# 1                          Primary/elementary school
# 6           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                        UndergradMajor  \
# Respondent
# ...

# %%
df.loc[[1,2]]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
df.loc[1:4, ["Country", "OpenSource"]]
# the loc will use normal string to get the columns
# Out:
#                            Country  \
# Respondent
# 1                   United Kingdom
# 2           Bosnia and Herzegovina
# 3                         Thailand
# 4                    United States
#
#                                                    OpenSource
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...

# %%
df["OpenSource"]
# Out:
# Respondent
# 1        The quality of OSS and closed source software ...
# 2        The quality of OSS and closed source software ...
# 3        The quality of OSS and closed source software ...
# 4        The quality of OSS and closed source software ...
# 5        OSS is, on average, of HIGHER quality than pro...
#                                ...
# 88377    The quality of OSS and closed source software ...
# 88601    The quality of OSS and closed source software ...
# 88802                                                  NaN
# 88816    OSS is, on average, of HIGHER quality than pro...
# 88863    OSS is, on average, of HIGHER quality than pro...
# Name: OpenSource, Length: 88883, dtype: object

# %%
# df.set_index("Respondent", inplace = True)
# use to set a coloumn as an index

# %%
# df.reset_index(inplace = True)
# used to reset the index back to default

# %%
schemea.loc["Sexuality", "QuestionText"]
# Out:
# 'Which of the following do you currently identify as? Please select all that apply. If you prefer not to answer, you may leave this question blank.'

# %%
# pd.set_option('display.max_rows', None)

# %%
schemea.sort_index(ascending = False)
# if i want to make it in descending order, inside the brackets i can put ascending = false
# Out:
#                                                     QuestionText
# Column
# YearsCodePro   How many years have you coded professionally (...
# YearsCode      Including any education, how many years have y...
# WorkWeekHrs     On average, how many hours per week do you work?
# WorkRemote                       How often do you work remotely?
# WorkPlan                 How structured or planned is your work?
# ...                                                          ...
# BlockchainOrg  How is your organization thinking about or imp...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BetterLife     Do you think people born today will have a bet...
# Age1stCode     At what age did you write your first line of c...
# Age            What is your age (in years)? If you prefer not...
#
# [85 rows x 1 columns]

# %%
filt = (df["Hobbyist"] == "Yes") & (df["Student"] == "No")

# %%
# df[filt]
df.loc[filt, "Student"]
# df.loc[filt, "Country"]
# adding a ~ to the filter will negate the filter
# Out:
# Respondent
# 1        No
# 3        No
# 5        No
# 6        No
# 9        No
#          ..
# 86566    No
# 86638    No
# 87352    No
# 88282    No
# 88377    No
# Name: Student, Length: 52150, dtype: object

# %%
higher = (df["ConvertedComp"] > 8000)

# %%
# df.loc[higher, ["Country", "ConvertedComp"]] 
df.loc[higher, "ConvertedComp"]
# Out:
# Respondent
# 3          8820.0
# 4         61000.0
# 6        366420.0
# 9         95179.0
# 10        13293.0
#            ...
# 88878    130000.0
# 88879     82488.0
# 88881     68745.0
# 88882    588012.0
# 88883     22915.0
# Name: ConvertedComp, Length: 51372, dtype: float64

# %%
countries = ["Spain", "Germany","Czech Republic", "United States"]
cut = df["Country"].isin(countries)

# %%
df.loc[cut,"Country"]
# Out:
# Respondent
# 4         United States
# 13        United States
# 14              Germany
# 22        United States
# 23        United States
#               ...
# 85642     United States
# 87739    Czech Republic
# 88212             Spain
# 88282     United States
# 88863             Spain
# Name: Country, Length: 29183, dtype: object

# %%
git =  df["LanguageWorkedWith"].str.contains("Python", na =False)

# %%
df.loc[git, "LanguageWorkedWith"]
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
df.columns = [x.upper() for x in df.columns]

# %%
df.rename(columns = {"MAINBRANCH" : "MAIN"}, inplace = True)

# %%
df.columns
# Out:
# Index(['MAIN', 'HOBBYIST', 'OPENSOURCER', 'OPENSOURCE', 'EMPLOYMENT',
#        'COUNTRY', 'STUDENT', 'EDLEVEL', 'UNDERGRADMAJOR', 'EDUOTHER',
#        'ORGSIZE', 'DEVTYPE', 'YEARSCODE', 'AGE1STCODE', 'YEARSCODEPRO',
#        'CAREERSAT', 'JOBSAT', 'MGRIDIOT', 'MGRMONEY', 'MGRWANT', 'JOBSEEK',
#        'LASTHIREDATE', 'LASTINT', 'FIZZBUZZ', 'JOBFACTORS', 'RESUMEUPDATE',
#        'CURRENCYSYMBOL', 'CURRENCYDESC', 'COMPTOTAL', 'COMPFREQ',
#        'CONVERTEDCOMP', 'WORKWEEKHRS', 'WORKPLAN', 'WORKCHALLENGE',
#        'WORKREMOTE', 'WORKLOC', 'IMPSYN', 'CODEREV', 'CODEREVHRS', 'UNITTESTS',
#        'PURCHASEHOW', 'PURCHASEWHAT', 'LANGUAGEWORKEDWITH',
#        'LANGUAGEDESIRENEXTYEAR', 'DATABASEWORKEDWITH',
#        'DATABASEDESIRENEXTYEAR', 'PLATFORMWORKEDWITH',
#        'PLATFORMDESIRENEXTYEAR', 'WEBFRAMEWORKEDWITH',
#        'WEBFRAMEDESIRENEXTYEAR', 'MISCTECHWORKEDWITH',
#        'MISCTECHDESIRENEXTYEAR', 'DEVENVIRON', 'OPSYS', 'CONTAINERS',
# ...

# %%
# pd.set_option("display.max_row", 85)

# %%
schemea
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %%
df.apply(pd.Series.min)
# this will give me an errror buh jst keep it
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df.apply(pd.Series.min)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:798, in FrameApply.apply_standard(self)
#     797 def apply_standard(self):
# --> 798     results, res_index = self.apply_series_generator()
# ...

# %%
# df.applymap(len)
# wouldn't work because of the data type i.e float and strings

# %%
df["HOBBYIST"] = df['HOBBYIST'].map({"Yes" : "True", "No" : "False"})
changwes

# %%
df["HOBBYIST"]

# %%
df["HOBBYIST"]+ " " + df["STUDENT"]

# %%
df["okay"] = df["HOBBYIST"] + " " +df["STUDENT"]

# %%
df

# %%
# i can split this okay by
# df["okay"].str.split(" ", expand = True)
# the .str turns it to string
# the .split turn splits the string where ever it sees space
# and the expand =  True expands the the strings adding them into different columns

# next i apply
# df[["the_first_column_name", "the_second_column_namw"]] = df["okay"].str.split(" ", expand = True)

# %%
df.drop(columns = ["okay"], inplace = True)

# %%
new_df = pd.DataFrame({"HOBBYIST": ["True"]})
df = new_df.append(df, ignore_index=True)

# %%
df
